# %% [markdown]
# | Modul                 | Methode                           | Was sie macht (kurz & praktisch)                                            |
# | --------------------- | --------------------------------- | --------------------------------------------------------------------------- |
# | `scipy.optimize`      | `minimize(fun, x0, ...)`          | Findet ein **Minimum** einer Funktion (numerische Optimierung).             |
# |                       | `curve_fit(f, xdata, ydata, ...)` | **Kurvenanpassung** (Least Squares) für Parameter in Modellen.              |
# |                       | `root(fun, x0, ...)`              | Findet **Nullstellen**/Lösungen von Gleichungssystemen `fun(x)=0`.          |
# |                       | `least_squares(fun, x0, ...)`     | Löst **nichtlineare Ausgleichsprobleme** (Residual-Minimierung).            |
# | `scipy.integrate`     | `quad(f, a, b)`                   | **Numerische Integration** 1D, sehr robust (∫ f(x) dx).                     |
# |                       | `dblquad(f, a, b, gfun, hfun)`    | **2D-Integration** über ein Gebiet.                                         |
# |                       | `solve_ivp(fun, t_span, y0, ...)` | Löst **Differentialgleichungen** (ODEs) flexibel (RK45 etc.).               |
# |                       | `simpson(y, x=...)`               | Integration aus diskreten Punkten per **Simpson-Regel**.                    |
# | `scipy.linalg`        | `solve(A, b)`                     | Löst **lineares Gleichungssystem** `A x = b`.                               |
# |                       | `inv(A)`                          | Berechnet **Matrixinverse** (oft besser: `solve`).                          |
# |                       | `svd(A)`                          | **Singulärwertzerlegung** (SVD) für Reduktion/Conditioning.                 |
# |                       | `eig(A)` / `eigh(A)`              | **Eigenwerte/-vektoren** (`eigh` für symmetrisch/hermitesch).               |
# | `scipy.sparse`        | `csr_matrix(...)`                 | Erzeugt **Sparse-Matrix** (speichereffizient, schnell bei großen Matrizen). |
# |                       | `diags(data, offsets)`            | Baut Sparse-Matrizen aus **Diagonalen** (z. B. Finite Differenzen).         |
# | `scipy.sparse.linalg` | `spsolve(A, b)`                   | Löst `A x=b` für **Sparse-Matrizen**.                                       |
# |                       | `cg(A, b, ...)`                   | **Conjugate Gradient**: iterativer Solver (für große SPD-Systeme).          |
# | `scipy.signal`        | `butter(N, Wn, btype=...)`        | Designt **Butterworth-Filter** (Low/High/Band).                             |
# |                       | `filtfilt(b, a, x)`               | Filtert **phasenfrei** (vorwärts+rückwärts, kein Delay).                    |
# |                       | `find_peaks(x, ...)`              | Findet **Peaks** in Signalen (mit Höhe/Abstand/Prominenz).                  |
# |                       | `spectrogram(x, fs=...)`          | Zeit-Frequenz-Analyse (**Spektrogramm**).                                   |
# | `scipy.fft`           | `fft(x)` / `ifft(X)`              | **FFT** und inverse FFT (Frequenzanalyse).                                  |
# |                       | `fftfreq(n, d=...)`               | Liefert **Frequenzachsen** passend zur FFT.                                 |
# | `scipy.stats`         | `norm`, `poisson`, `expon`, ...   | Verteilungen als Objekte (PDF/CDF/RVS).                                     |
# |                       | `ttest_ind(a, b, ...)`            | **t-Test** für zwei unabhängige Stichproben.                                |
# |                       | `pearsonr(x, y)`                  | **Pearson-Korrelation** + p-Wert.                                           |
# |                       | `linregress(x, y)`                | Einfache **lineare Regression** (Steigung, Achsenabschnitt, p-Wert).        |
# |                       | `zscore(x)`                       | Standardisiert Daten zu **z-Werten**.                                       |
# | `scipy.interpolate`   | `interp1d(x, y, kind=...)`        | **1D-Interpolation** (linear, kubisch, …).                                  |
# |                       | `CubicSpline(x, y)`               | **Glatter kubischer Spline** (oft schöner als `interp1d`).                  |
# | `scipy.ndimage`       | `gaussian_filter(img, sigma)`     | **Gaussian Blur** für Arrays/Bilder.                                        |
# |                       | `sobel(img, axis=...)`            | **Kantenfilter** (Gradientenapproximation).                                 |
# | `scipy.spatial`       | `distance.cdist(A, B)`            | Paarweise **Distanzen** zwischen Punktmengen.                               |
# |                       | `KDTree(data).query(p)`           | **Schnelle Nachbarsuche** (Nearest Neighbor).                               |
