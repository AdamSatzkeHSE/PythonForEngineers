# %% [markdown]
# ## Funktionen in Python
#
# Funktionen lassen uns konkrete - wierholte Operationen in einem Codeblock definieren.

# %%
"""
Ausgangssituation:
Ein Datenlogger hat mehrere Messungen von Spannung
und Strom aufgezeichnet. Die elektrische Leistung
soll für jede Messung berechnet werden.
"""

voltages = [5.0, 5.1, 4.9, 5.2]
currents = [0.2, 0.21, 0.19, 0.22]

# # Schreibe hier deinen Code
# for i in range()
for i in range(len(voltages)):
    power = voltages[i] * currents[i]
    print(power) 

voltages = [5.0, 5.1, 4.9, 5.2]
currents = [0.2, 0.21, 0.19, 0.22]

# # Schreibe hier deinen Code
# for i in range()
for i in range(len(voltages)):
    power = voltages[i] * currents[i]
    print(power) 

voltages = [5.0, 5.1, 4.9, 5.2]
currents = [0.2, 0.21, 0.19, 0.22]

# # Schreibe hier deinen Code
# for i in range()
for i in range(len(voltages)):
    power = voltages[i] * currents[i]
    print(power) 

voltages = [5.0, 5.1, 4.9, 5.2]
currents = [0.2, 0.21, 0.19, 0.22]

# # Schreibe hier deinen Code
# for i in range()
for i in range(len(voltages)):
    power = voltages[i] * currents[i]
    print(power)

# %%
# Funktionen: Syntax

def power_function(voltage, current):
    leistung = voltage * current
    print(f"Leistung {leistung:.2f} W wurde berechnet.")

    # Keyword optional: return
    return leistung
    
voltages = [5.0, 5.1, 4.9, 5.2]
currents = [0.2, 0.21, 0.19, 0.22]

for i in range(len(voltages)):
    power = power_function(voltages[i], currents[i])
# Out:
# Leistung 1.00 W wurde berechnet.
# Leistung 1.07 W wurde berechnet.
# Leistung 0.93 W wurde berechnet.
# Leistung 1.14 W wurde berechnet.

# %%
# Version 2 mit Listen als Funktionsargumenten



def power_function_2(voltages, currents):
    """ power_function_2:
    Nimmt die Messwerte-Liste von Spannungen und Strömen
    und gibt eine Liste mit den Leistungswerten zurück.
    """
    power = []
    # Wie kann ich jetzt die Listen benutzen?
    for i in range(len(voltages)):
        leistung = voltages[i] * currents[i]
        # Kein return, sondern Information.
        # print(leistung)
        power.append(leistung)
    return power

### Main Code ###
voltages = [5.0, 5.1, 4.9, 5.2]
currents = [0.2, 0.21, 0.19, 0.22]
result_1 = power_function_2(voltages, currents)

# voltages = [5.0, 5.1, 4.9, 5.2]
# currents = [0.2, 0.21, 0.19, 0.22]
# result_2 = power_function_2(voltages, currents)

# voltages = [5.0, 5.1, 4.9, 5.2]
# currents = [0.2, 0.21, 0.19, 0.22]
# result_3 = power_function_2(voltages, currents)

# voltages = [5.0, 5.1, 4.9, 5.2]
# currents = [0.2, 0.21, 0.19, 0.22]
# result_4 = power_function_2(voltages, currents)

messwerte = {
    "voltages": [voltages_1, voltages_2, voltages_3],
    "currents": [currents_1, currents_2, currents_3]
}
# print(result_1)
# print(result_2)
# print(result_3)
# print(result_4)
for i in messwerte["voltages"]:
    result = power_function_2(messwerte["voltages"], messwerte["currents"])
# Out:
# [1.0, 1.071, 0.931, 1.1440000000000001]
# [1.0, 1.071, 0.931, 1.1440000000000001]
# [1.0, 1.071, 0.931, 1.1440000000000001]
# [1.0, 1.071, 0.931, 1.1440000000000001]
