# %% [markdown]
# ### Dictionaries in Python

# %%
# Dictionaries in Python bestehen aus sogenannten Key-Value - Pairs.

coffee = {
    "Espresso": 2,
    "Milchkaffee": 4,
    "Capuccino": "nicht erlaubt"
}

# Zugriff auf Werte (Values) mittels (Schluessel) Key
print(coffee["Espresso"])
print(coffee["Capuccino"])
print(coffee["Milchkaffee"])
# Out:
# 2
# nicht erlaubt
# 4

# %%
# Mit Dictionaries arbeiten:

# mit items()
print("Mit items:")
for coffeesort, counter in coffee.items():
    print(f"Key {coffeesort} hat Value {counter}")

# mit keys()
print("Mit Keys:")
for i in coffee.keys():
    print(f"{i}: {coffee[i]}")

# values()
print("Mit values:")
for v in coffee.values():
    print("Value:", v)
# Out:
# Mit items:
# Key Espresso hat Value 2
# Key Milchkaffee hat Value 4
# Key Capuccino hat Value nicht erlaubt
# Mit Keys:
# Espresso: 2.000
# Milchkaffee: 4.000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 11
#       9 print("Mit Keys:")
#      10 for i in coffee.keys():
# ---> 11     print(f"{i}: {coffee[i]:.3f}")
#      13 # values()
#      14 print("Mit values:")
#
# ValueError: Unknown format code 'f' for object of type 'str'
