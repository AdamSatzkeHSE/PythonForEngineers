# %% [markdown]
# # Anaconda + VS Code Test
#
# Dieses Notebook prüft:
#
# - Python läuft
# - Conda-Environment aktiv
# - Pakete funktionieren

# %%
import sys
import platform

print("Python Version:", sys.version)
print("Platform:", platform.platform())
print(sys.executable)
# Out:
# Python Version: 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]
# Platform: Windows-10-10.0.22631-SP0
# c:\Users\Adams\miniconda3\envs\myenv\python.exe

# %%
# Data Science Test

import numpy as np
import pandas as pd

data = pd.DataFrame({
    "x": np.arange(5),
    "y": np.arange(5) ** 2,
})

data
# Out:
#    x   y
# 0  0   0
# 1  1   1
# 2  2   4
# 3  3   9
# 4  4  16

# %%
# Plot Test

# %conda install matplotplib
# Funktioniert immer
# import sys
# !{sys.executable} -m pip install numpy pandas
import matplotlib.pyplot as plt

plt.plot(data["x"], data["y"])
plt.title("Test Plot")
plt.show()
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - matplotplib
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %% [markdown]
# # Typische Fehler
#
# - Falscher Interpreter im VS-Code
# - Environment nicht richtig aktiviert
# - Jupyter Extension fehlt
# - VS-Code nach Installation nicht neu gestartet.
#
# Ursache meistens: Der Shell hat die Conda-Initialisierung noch nicht geladen, oder du hast das Terminal nach der Installation nicht neu gestartet.

# %% [markdown]
# ## Nützliche Standardbefehle
#
# conda activate pyproj
#
# conda install requests
#
# conda remove -n pyproj --all
