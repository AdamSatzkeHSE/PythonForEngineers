# %% [markdown]
# ## Das Scipy Modul
# Scipy ist ein mächtiges Python Modul für wissenschaftliches und technisches Rechnen.
# Es baut auf Numpy auf und liefert fertige Werkzeige für komplexe Mathematik, Datenanalyse und Ingenieurarbeiten.

# %% [markdown]
# - Numpy: schnelle Arrays und Grundrechnen
# - Scipy: fortgeschrittene mathematische Algorithmen

# %%
import numpy as np

rng = np.random.default_rng(0)
print(rng)
# Out:
# Generator(PCG64)
